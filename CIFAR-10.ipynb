# %% [markdown]
# ##### Cell 1: load of CIFAR‑10, display somes images.

# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# ------------------------------------------------------------------
# Load the pre-downloaded CIFAR-10 batches (NumPy only)
# ------------------------------------------------------------------
# CIFAR-10 is stored in `Dataset/cifar-10-python/cifar-10-batches-py`
data_root = Path("Dataset") / "cifar-10-python" / "cifar-10-batches-py"

def _load_cifar_batch(file_path):
    """Load a single CIFAR-10 batch file (Python pickled dict).
    Returns flat images (N, 3072) float32 in [0, 1] and labels (N,) int64.
    """
    import pickle

    with open(file_path, "rb") as f:
        batch = pickle.load(f, encoding="bytes")
    # Keys are b"data" and b"labels" in the original CIFAR-10 python version
    # Convert raw uint8 pixels to normalized flat vectors in [0, 1]
    data = batch[b"data"].astype(np.float32) / 255.0   # (N, 3072)
    labels = np.array(batch[b"labels"], dtype=np.int64)  # (N,)
    return data, labels

# Load training batches (data_batch_1-5)
train_images_list = []
train_labels_list = []
for i in range(1, 6):
    batch_file = data_root / f"data_batch_{i}"
    imgs, lbls = _load_cifar_batch(batch_file)
    train_images_list.append(imgs)
    train_labels_list.append(lbls)

x_train_full = np.concatenate(train_images_list, axis=0)  # (50000, 3072)
y_train_full = np.concatenate(train_labels_list, axis=0)  # (50000,)
print("full train images", x_train_full.shape)
print("full train labels", y_train_full.shape)

# Load test batch
x_test_full, y_test_full = _load_cifar_batch(data_root / "test_batch")  # (10000, 3072), (10000,)
print("full test images", x_test_full.shape)
print("full test labels", y_test_full.shape)
# ------------------------------------------------------------------
# Create subsets: 40,000 for training, 10,000 for validation (from 50,000 train)
# Same style as Fashion-MNIST notebook
# ------------------------------------------------------------------
x_train = x_train_full[:40000]
y_train = y_train_full[:40000]

x_valid = x_train_full[40000:50000]
y_valid = y_train_full[40000:50000]

x_test = x_test_full
y_test = y_test_full

# Number of classes (should be 10 for CIFAR-10)
unique_labels = np.unique(y_train)
num_classes = unique_labels.size

# CIFAR-10 official label names
cifar10_label_map = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck",
}
class_names = np.array([
    cifar10_label_map.get(int(lbl), f"class_{int(lbl)}")
    for lbl in unique_labels
])
print(" Splitting data CIFAR-10:")
print("  x_train:", x_train.shape, x_train.dtype)
print("  y_train:", y_train.shape, y_train.dtype)
print("  x_valid:", x_valid.shape, x_valid.dtype)
print("  y_valid:", y_valid.shape, y_valid.dtype)
print("  x_test :", x_test.shape, x_test.dtype)
print("  y_test :", y_test.shape, y_test.dtype)
print("Number of classes:", num_classes)
print("Class names:", class_names.tolist())

# Optional: quick visualization of a 10x10 grid like Fashion-MNIST
n = x_train.shape[0]
idx = np.random.permutation(n)[:100]

# x_train is flat (N, 3072); reshape to (N, 32, 32, 3) for plotting
images_flat = x_train[idx]              # (100, 3072)
labels = y_train[idx]                   # (100,)
images = images_flat.reshape(-1, 3, 32, 32)
images = np.transpose(images, (0, 2, 3, 1))  # (100, 32, 32, 3)

rows, columns = 10, 10
height, width = images.shape[1], images.shape[2]  # 32, 32
grid = np.zeros((rows * height, columns * width, 3), dtype=images.dtype)

for i in range(rows * columns):
    r = i // columns
    c = i % columns
    grid[r*height:(r+1)*height, c*width:(c+1)*width, :] = images[i]

plt.figure(figsize=(7, 7))
plt.imshow(grid)
plt.axis("off")
plt.show()

print("images_flat shape:", images_flat.shape)
print("images shape:", images.shape)
print("labels shape:", labels.shape)
# Out:
# full train images (50000, 3072)
# full train labels (50000,)
# full test images (10000, 3072)
# full test labels (10000,)
#  Splitting data CIFAR-10:
#   x_train: (40000, 3072) float32
#   y_train: (40000,) int64
#   x_valid: (10000, 3072) float32
#   y_valid: (10000,) int64
#   x_test : (10000, 3072) float32
#   y_test : (10000,) int64
# Number of classes: 10
# Class names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# images_flat shape: (100, 3072)
# images shape: (100, 32, 32, 3)
# labels shape: (100,)

# %% [markdown]
# #####  Cell 2: Runs sweeps on CIFAR‑10, logging result to W&B

# %%
import importlib
import os
import pandas as pd
import matplotlib.pyplot as plt

import Utilisfunction as utils_module
importlib.reload(utils_module)
run_wandb_sweep = utils_module.run_wandb_sweep
summarize_activation_init_performance = utils_module.summarize_activation_init_performance
build_activation_init_summary_dataframe = utils_module.build_activation_init_summary_dataframe

# ==============================================================
# Launch W&B sweeps for CIFAR-10 (NumPy-only model)
# Same structure as Fashion-MNIST sweeps
# ==============================================================
use_wandb = True
try:
    wandb = importlib.import_module("wandb")
except ImportError:
    wandb = None
    use_wandb = False
    print("wandb is not installed; continuing without sweep logging.")

if use_wandb:
    try:
        wandb.finish()
    except Exception:
        pass
    os.environ.pop("WANDB_RUN_ID", None)
    os.environ.pop("WANDB_RESUME", None)

    sweep_specs = [
        {
            "activation": "relu",
            "weights_init": "he",
            "name": "cifar10-ffnn-relu-he",
        },
        {
            "activation": "tanh",
            "weights_init": "xavier",
            "name": "cifar10-ffnn-tanh-xavier",
        },
        {           
             "activation": "sigmoid",
            "weights_init": "xavier",
            "name": "cifar10-ffnn-sigmoid-xavier",
       },
                           
    ]

    sweep_ids = []
    for spec in sweep_specs:
        activation = spec["activation"]
        weights_init = spec["weights_init"]
        sweep_name = spec["name"]
        print(f"Launching CIFAR-10 sweep for activation={activation}, weights_init={weights_init}")
        overrides = {
            "parameters": {
                "activation": {"values": [activation]},
                "weights_init": {"values": [weights_init]},
            }
        }
        sweep_id = run_wandb_sweep(
            method="Bayesian",
            X_train=x_train,
            y_train=y_train,
            X_valid=x_valid,
            y_valid=y_valid,
            X_test=x_test,
            y_test=y_test,
            class_names=class_names,
            project="cifar10-ffnn",
            sweep_name=sweep_name,
            count=1,
            config_overrides=overrides,
            dataset_name="CIFAR-10",
        )
        sweep_ids.append(sweep_id)
        print(f"Launched CIFAR-10 sweep: {sweep_id}")
else:
    print("Skipping CIFAR-10 sweep launch because wandb is unavailable.")
# Out:
# Launching CIFAR-10 sweep for activation=relu, weights_init=he
# Create sweep with ID: uhua2v36
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/uhua2v36
# wandb: Agent Starting Run: 4wmtfc10 with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: he
# wandb: Currently logged in as: jakubbouzan (jakubbouzan-danmarks-tekniske-universitet-dtu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_225354-4wmtfc10</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/4wmtfc10' target="_blank">comfy-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/uhua2v36' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/uhua2v36</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/uhua2v36' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/uhua2v36</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/4wmtfc10' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/4wmtfc10</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: he
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 1.9020, train acc: 0.3191 | valid loss: 1.7774, valid acc: 0.3711
# Epoch 01 | validation step 0800 | train loss: 1.7151, train acc: 0.3884 | valid loss: 1.7457, valid acc: 0.3760
# Epoch 02 | validation step 1200 | train loss: 1.6443, train acc: 0.4148 | valid loss: 1.6315, valid acc: 0.4264
# Epoch 03 | validation step 1600 | train loss: 1.5792, train acc: 0.4385 | valid loss: 1.6639, valid acc: 0.4152
# Epoch 04 | validation step 2000 | train loss: 1.5431, train acc: 0.4517 | valid loss: 1.5896, valid acc: 0.4376
# Epoch 05 | validation step 2400 | train loss: 1.5144, train acc: 0.4630 | valid loss: 1.5470, valid acc: 0.4603
# Epoch 06 | validation step 2800 | train loss: 1.4798, train acc: 0.4739 | valid loss: 1.5398, valid acc: 0.4632
# Epoch 07 | validation step 3200 | train loss: 1.4517, train acc: 0.4857 | valid loss: 1.5642, valid acc: 0.4440
# Epoch 08 | validation step 3600 | train loss: 1.4340, train acc: 0.4924 | valid loss: 1.4872, valid acc: 0.4783
# Epoch 09 | validation step 4000 | train loss: 1.4075, train acc: 0.4978 | valid loss: 1.4791, valid acc: 0.4760
# Epoch 10 | validation step 4400 | train loss: 1.3846, train acc: 0.5099 | valid loss: 1.4754, valid acc: 0.4817
# Epoch 11 | validation step 4800 | train loss: 1.3681, train acc: 0.5150 | valid loss: 1.5093, valid acc: 0.4683
# Epoch 12 | validation step 5200 | train loss: 1.3574, train acc: 0.5175 | valid loss: 1.4536, valid acc: 0.4930
# Epoch 13 | validation step 5600 | train loss: 1.3348, train acc: 0.5247 | valid loss: 1.4214, valid acc: 0.4998
# Epoch 14 | validation step 6000 | train loss: 1.3236, train acc: 0.5318 | valid loss: 1.4370, valid acc: 0.4920
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>█▆▄▃▂▂▁▁▁▁▁▁▂▁▁</td></tr><tr><td>grad_norms/layer_1</td><td>▅█▄▃▂▃▁▂▂▄▃▄▆▆▆</td></tr><tr><td>grad_norms/layer_2</td><td>▅█▇▇▆▆▅▄▄▄▃▃▂▂▁</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▃▄▅▅▆▆▆▇▇▇▇███</td></tr><tr><td>metrics/train_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▁▄▃▅▆▆▅▇▇▇▆███</td></tr><tr><td>metrics/valid_loss</td><td>█▇▅▆▄▃▃▄▂▂▂▃▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>2.26276</td></tr><tr><td>grad_norms/layer_1</td><td>1.42159</td></tr><tr><td>grad_norms/layer_2</td><td>1.18863</td></tr><tr><td>metrics/test_accuracy</td><td>0.4965</td></tr><tr><td>metrics/train_accuracy</td><td>0.5318</td></tr><tr><td>metrics/train_loss</td><td>1.32358</td></tr><tr><td>metrics/valid_accuracy</td><td>0.492</td></tr><tr><td>metrics/valid_loss</td><td>1.43699</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comfy-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/4wmtfc10' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/4wmtfc10</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 5 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_225354-4wmtfc10\logs</code>
# Launched CIFAR-10 sweep: uhua2v36
# Launching CIFAR-10 sweep for activation=tanh, weights_init=xavier
# Create sweep with ID: 31z14nls
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/31z14nls
# wandb: Agent Starting Run: 5m01nc1a with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: xavier
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_230329-5m01nc1a</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5m01nc1a' target="_blank">colorful-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/31z14nls' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/31z14nls</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/31z14nls' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/31z14nls</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5m01nc1a' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5m01nc1a</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: xavier
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 1.9007, train acc: 0.3201 | valid loss: 1.7687, valid acc: 0.3700
# Epoch 01 | validation step 0800 | train loss: 1.7032, train acc: 0.3939 | valid loss: 1.6543, valid acc: 0.4216
# Epoch 02 | validation step 1200 | train loss: 1.6338, train acc: 0.4184 | valid loss: 1.6430, valid acc: 0.4248
# Epoch 03 | validation step 1600 | train loss: 1.5850, train acc: 0.4367 | valid loss: 1.6091, valid acc: 0.4342
# Epoch 04 | validation step 2000 | train loss: 1.5507, train acc: 0.4476 | valid loss: 1.6703, valid acc: 0.4065
# Epoch 05 | validation step 2400 | train loss: 1.5107, train acc: 0.4592 | valid loss: 1.5523, valid acc: 0.4489
# Epoch 06 | validation step 2800 | train loss: 1.4833, train acc: 0.4689 | valid loss: 1.5422, valid acc: 0.4467
# Epoch 07 | validation step 3200 | train loss: 1.4732, train acc: 0.4745 | valid loss: 1.5463, valid acc: 0.4499
# Epoch 08 | validation step 3600 | train loss: 1.4472, train acc: 0.4842 | valid loss: 1.5813, valid acc: 0.4342
# Epoch 09 | validation step 4000 | train loss: 1.4268, train acc: 0.4911 | valid loss: 1.5066, valid acc: 0.4714
# Epoch 10 | validation step 4400 | train loss: 1.4177, train acc: 0.4932 | valid loss: 1.4465, valid acc: 0.4913
# Epoch 11 | validation step 4800 | train loss: 1.4029, train acc: 0.5003 | valid loss: 1.5713, valid acc: 0.4364
# Epoch 12 | validation step 5200 | train loss: 1.3890, train acc: 0.5030 | valid loss: 1.4565, valid acc: 0.4828
# Epoch 13 | validation step 5600 | train loss: 1.3665, train acc: 0.5121 | valid loss: 1.4587, valid acc: 0.4769
# Epoch 14 | validation step 6000 | train loss: 1.3637, train acc: 0.5153 | valid loss: 1.4781, valid acc: 0.4740
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>█▄▃▂▁▁▁▁▂▂▂▃▃▃▄</td></tr><tr><td>grad_norms/layer_1</td><td>▅▃▄▂▂▁▁▂▃▂▄▅▆▄█</td></tr><tr><td>grad_norms/layer_2</td><td>▁▃▆▇█▇▆█▇▆▆▆▇▄▅</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>metrics/train_loss</td><td>█▅▅▄▃▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▄▄▅▃▆▅▆▅▇█▅█▇▇</td></tr><tr><td>metrics/valid_loss</td><td>█▆▅▅▆▃▃▃▄▂▁▄▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>2.26926</td></tr><tr><td>grad_norms/layer_1</td><td>1.40583</td></tr><tr><td>grad_norms/layer_2</td><td>1.06554</td></tr><tr><td>metrics/test_accuracy</td><td>0.4833</td></tr><tr><td>metrics/train_accuracy</td><td>0.5153</td></tr><tr><td>metrics/train_loss</td><td>1.36373</td></tr><tr><td>metrics/valid_accuracy</td><td>0.474</td></tr><tr><td>metrics/valid_loss</td><td>1.47812</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5m01nc1a' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5m01nc1a</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 5 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_230329-5m01nc1a\logs</code>
# Launched CIFAR-10 sweep: 31z14nls
# Launching CIFAR-10 sweep for activation=sigmoid, weights_init=xavier
# Create sweep with ID: qlzizw6e
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/qlzizw6e
# wandb: Agent Starting Run: xczg20wr with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: xavier
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_230749-xczg20wr</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/xczg20wr' target="_blank">graceful-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/qlzizw6e' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/qlzizw6e</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/qlzizw6e' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/qlzizw6e</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/xczg20wr' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/xczg20wr</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: xavier
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 2.1024, train acc: 0.2498 | valid loss: 1.9172, valid acc: 0.3249
# Epoch 01 | validation step 0800 | train loss: 1.8522, train acc: 0.3427 | valid loss: 1.8113, valid acc: 0.3606
# Epoch 02 | validation step 1200 | train loss: 1.7779, train acc: 0.3698 | valid loss: 1.7808, valid acc: 0.3625
# Epoch 03 | validation step 1600 | train loss: 1.7261, train acc: 0.3858 | valid loss: 1.7143, valid acc: 0.3942
# Epoch 04 | validation step 2000 | train loss: 1.6993, train acc: 0.3942 | valid loss: 1.7253, valid acc: 0.3833
# Epoch 05 | validation step 2400 | train loss: 1.6616, train acc: 0.4082 | valid loss: 1.6755, valid acc: 0.3963
# Epoch 06 | validation step 2800 | train loss: 1.6435, train acc: 0.4136 | valid loss: 1.6544, valid acc: 0.4109
# Epoch 07 | validation step 3200 | train loss: 1.6261, train acc: 0.4202 | valid loss: 1.6564, valid acc: 0.4069
# Epoch 08 | validation step 3600 | train loss: 1.5998, train acc: 0.4341 | valid loss: 1.6062, valid acc: 0.4330
# Epoch 09 | validation step 4000 | train loss: 1.5936, train acc: 0.4326 | valid loss: 1.6277, valid acc: 0.4175
# Epoch 10 | validation step 4400 | train loss: 1.5770, train acc: 0.4389 | valid loss: 1.6064, valid acc: 0.4294
# Epoch 11 | validation step 4800 | train loss: 1.5638, train acc: 0.4478 | valid loss: 1.5841, valid acc: 0.4432
# Epoch 12 | validation step 5200 | train loss: 1.5471, train acc: 0.4501 | valid loss: 1.5691, valid acc: 0.4441
# Epoch 13 | validation step 5600 | train loss: 1.5449, train acc: 0.4513 | valid loss: 1.5660, valid acc: 0.4454
# Epoch 14 | validation step 6000 | train loss: 1.5325, train acc: 0.4545 | valid loss: 1.5772, valid acc: 0.4386
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>▁▂▃▄▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>grad_norms/layer_1</td><td>▂▁▂▂▄▃▄▅▄▆▆▇▇██</td></tr><tr><td>grad_norms/layer_2</td><td>▇▂▄▄█▂▇▇▁▇▆▄▄▆▄</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▄▅▆▆▆▇▇▇▇▇████</td></tr><tr><td>metrics/train_loss</td><td>█▅▄▃▃▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▃▃▅▄▅▆▆▇▆▇████</td></tr><tr><td>metrics/valid_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>0.92104</td></tr><tr><td>grad_norms/layer_1</td><td>0.42372</td></tr><tr><td>grad_norms/layer_2</td><td>0.84041</td></tr><tr><td>metrics/test_accuracy</td><td>0.4483</td></tr><tr><td>metrics/train_accuracy</td><td>0.45453</td></tr><tr><td>metrics/train_loss</td><td>1.53249</td></tr><tr><td>metrics/valid_accuracy</td><td>0.4386</td></tr><tr><td>metrics/valid_loss</td><td>1.57719</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">graceful-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/xczg20wr' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/xczg20wr</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 5 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_230749-xczg20wr\logs</code>
# Launched CIFAR-10 sweep: qlzizw6e

# %% [markdown]
# #### Summary CIFAR-10 comparing activation functions and initializations (local only)

# %%
# ==============================================================
# Summarise CIFAR-10 activation/initialisation performance (local only)
# ==============================================================
summaries = summarize_activation_init_performance(
    project="cifar10-ffnn",
    # entity="jakubbouzan",  # set if needed
    print_table=False,
)

if summaries:
    summary_table_df = build_activation_init_summary_dataframe(summaries)
    display(summary_table_df)

    import pandas as pd
    raw_df = pd.DataFrame(summaries)
    pivot_df = raw_df.pivot(
        index="activation",
        columns="weights_init",
        values="best_valid_acc_mean",
    )
    fig, ax = plt.subplots(figsize=(6, 4))
    pivot_df.plot(kind="bar", ax=ax)
    ax.set_ylabel("Mean Best Validation Accuracy")
    ax.set_xlabel("Activation")
    ax.set_title("CIFAR-10: Activation vs. Initialisation Performance")
    ax.set_ylim(0, 1)
    ax.legend(title="Initialisation")
    plt.tight_layout()
    plt.show()
else:
    print("No CIFAR-10 runs were found to summarise. Ensure sweeps finished and try again.")
# Out:
#   Activation Weights Init  Run Count  Best Validation Mean  \
# 0       relu           he          1                0.4998
# 1       tanh       xavier          1                0.4913
# 2    sigmoid       xavier          1                0.4454
#
#    Best Validation Max  Final Validation Mean  Final Validation Max  \
# 0               0.4998                 0.4920                0.4920
# 1               0.4913                 0.4740                0.4740
# 2               0.4454                 0.4386                0.4386
#
#    Final Training Mean  Final Training Max
# 0             0.531800            0.531800
# 1             0.515300            0.515300
# 2             0.454525            0.454525
