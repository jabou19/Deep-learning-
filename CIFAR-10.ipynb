# %% [markdown]
# ##### Cell 1: load of CIFAR‑10, display somes images.

# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# ------------------------------------------------------------------
# Load the pre-downloaded CIFAR-10 batches (NumPy only)
# ------------------------------------------------------------------
# CIFAR-10 is stored in `Dataset/cifar-10-python/cifar-10-batches-py`
data_root = Path("Dataset") / "cifar-10-python" / "cifar-10-batches-py"

def _load_cifar_batch(file_path):
    """Load a single CIFAR-10 batch file (Python pickled dict).
    Returns flat images (N, 3072) float32 in [0, 1] and labels (N,) int64.
    """
    import pickle

    with open(file_path, "rb") as f:
        batch = pickle.load(f, encoding="bytes")
    # Keys are b"data" and b"labels" in the original CIFAR-10 python version
    # Convert raw uint8 pixels to normalized flat vectors in [0, 1]
    data = batch[b"data"].astype(np.float32) / 255.0   # (N, 3072)
    labels = np.array(batch[b"labels"], dtype=np.int64)  # (N,)
    return data, labels

# Load training batches (data_batch_1-5)
train_images_list = []
train_labels_list = []
for i in range(1, 6):
    batch_file = data_root / f"data_batch_{i}"
    imgs, lbls = _load_cifar_batch(batch_file)
    train_images_list.append(imgs)
    train_labels_list.append(lbls)

x_train_full = np.concatenate(train_images_list, axis=0)  # (50000, 3072)
y_train_full = np.concatenate(train_labels_list, axis=0)  # (50000,)
print("full train images", x_train_full.shape)
print("full train labels", y_train_full.shape)

# Load test batch
x_test_full, y_test_full = _load_cifar_batch(data_root / "test_batch")  # (10000, 3072), (10000,)
print("full test images", x_test_full.shape)
print("full test labels", y_test_full.shape)
# ------------------------------------------------------------------
# Create subsets: 40,000 for training, 10,000 for validation (from 50,000 train)
# Same style as Fashion-MNIST notebook
# ------------------------------------------------------------------
x_train = x_train_full[:40000]
y_train = y_train_full[:40000]

x_valid = x_train_full[40000:50000]
y_valid = y_train_full[40000:50000]

x_test = x_test_full
y_test = y_test_full

# Number of classes (should be 10 for CIFAR-10)
unique_labels = np.unique(y_train)
num_classes = unique_labels.size

# CIFAR-10 official label names
cifar10_label_map = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck",
}
class_names = np.array([
    cifar10_label_map.get(int(lbl), f"class_{int(lbl)}")
    for lbl in unique_labels
])
print(" Splitting data CIFAR-10:")
print("  x_train:", x_train.shape, x_train.dtype)
print("  y_train:", y_train.shape, y_train.dtype)
print("  x_valid:", x_valid.shape, x_valid.dtype)
print("  y_valid:", y_valid.shape, y_valid.dtype)
print("  x_test :", x_test.shape, x_test.dtype)
print("  y_test :", y_test.shape, y_test.dtype)
print("Number of classes:", num_classes)
print("Class names:", class_names.tolist())

# Optional: quick visualization of a 10x10 grid like Fashion-MNIST
n = x_train.shape[0]
idx = np.random.permutation(n)[:100]

# x_train is flat (N, 3072); reshape to (N, 32, 32, 3) for plotting
images_flat = x_train[idx]              # (100, 3072)
labels = y_train[idx]                   # (100,)
images = images_flat.reshape(-1, 3, 32, 32)
images = np.transpose(images, (0, 2, 3, 1))  # (100, 32, 32, 3)

rows, columns = 10, 10
height, width = images.shape[1], images.shape[2]  # 32, 32
grid = np.zeros((rows * height, columns * width, 3), dtype=images.dtype)

for i in range(rows * columns):
    r = i // columns
    c = i % columns
    grid[r*height:(r+1)*height, c*width:(c+1)*width, :] = images[i]

plt.figure(figsize=(7, 7))
plt.imshow(grid)
plt.axis("off")
plt.show()

print("images_flat shape:", images_flat.shape)
print("images shape:", images.shape)
print("labels shape:", labels.shape)
# Out:
# full train images (50000, 3072)
# full train labels (50000,)
# full test images (10000, 3072)
# full test labels (10000,)
#  Splitting data CIFAR-10:
#   x_train: (40000, 3072) float32
#   y_train: (40000,) int64
#   x_valid: (10000, 3072) float32
#   y_valid: (10000,) int64
#   x_test : (10000, 3072) float32
#   y_test : (10000,) int64
# Number of classes: 10
# Class names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# images_flat shape: (100, 3072)
# images shape: (100, 32, 32, 3)
# labels shape: (100,)

# %% [markdown]
# #####  Cell 2: Runs sweeps on CIFAR‑10, logging result to W&B

# %%
import importlib
import os
import pandas as pd
import matplotlib.pyplot as plt

import Utilisfunction as utils_module
importlib.reload(utils_module)
run_wandb_sweep = utils_module.run_wandb_sweep
summarize_activation_init_performance = utils_module.summarize_activation_init_performance
build_activation_init_summary_dataframe = utils_module.build_activation_init_summary_dataframe

# ==============================================================
# Launch W&B sweeps for CIFAR-10 (NumPy-only model)
# Same structure as Fashion-MNIST sweeps
# ==============================================================
use_wandb = True
try:
    wandb = importlib.import_module("wandb")
except ImportError:
    wandb = None
    use_wandb = False
    print("wandb is not installed; continuing without sweep logging.")

if use_wandb:
    try:
        wandb.finish()
    except Exception:
        pass
    os.environ.pop("WANDB_RUN_ID", None)
    os.environ.pop("WANDB_RESUME", None)

    sweep_specs = [
        {
            "activation": "relu",
            "weights_init": "he",
            "name": "cifar10-ffnn-relu-he",
        },
        {
            "activation": "tanh",
            "weights_init": "xavier",
            "name": "cifar10-ffnn-tanh-xavier",
        },
        {           
             "activation": "sigmoid",
            "weights_init": "xavier",
            "name": "cifar10-ffnn-sigmoid-xavier",
       },
                           
    ]

    sweep_ids = []
    for spec in sweep_specs:
        activation = spec["activation"]
        weights_init = spec["weights_init"]
        sweep_name = spec["name"]
        print(f"Launching CIFAR-10 sweep for activation={activation}, weights_init={weights_init}")
        overrides = {
            "parameters": {
                "activation": {"values": [activation]},
                "weights_init": {"values": [weights_init]},
            }
        }
        sweep_id = run_wandb_sweep(
            method="Bayesian",
            X_train=x_train,
            y_train=y_train,
            X_valid=x_valid,
            y_valid=y_valid,
            X_test=x_test,
            y_test=y_test,
            class_names=class_names,
            project="cifar10-ffnn",
            sweep_name=sweep_name,
            count=1,
            config_overrides=overrides,
        )
        sweep_ids.append(sweep_id)
        print(f"Launched CIFAR-10 sweep: {sweep_id}")
else:
    print("Skipping CIFAR-10 sweep launch because wandb is unavailable.")
# Out:
# Launching CIFAR-10 sweep for activation=relu, weights_init=he
# Create sweep with ID: snxiru39
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/snxiru39
# wandb: Agent Starting Run: 8z0briyh with config:
# wandb: 	activation: relu
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: he
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_200226-8z0briyh</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/8z0briyh' target="_blank">stellar-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/snxiru39' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/snxiru39</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/snxiru39' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/snxiru39</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/8z0briyh' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/8z0briyh</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: he
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 1.9182, train acc: 0.3159 | valid loss: 1.7990, valid acc: 0.3654
# Epoch 01 | validation step 0800 | train loss: 1.7297, train acc: 0.3853 | valid loss: 1.7630, valid acc: 0.3786
# Epoch 02 | validation step 1200 | train loss: 1.6432, train acc: 0.4166 | valid loss: 1.6558, valid acc: 0.4155
# Epoch 03 | validation step 1600 | train loss: 1.5857, train acc: 0.4397 | valid loss: 1.6318, valid acc: 0.4288
# Epoch 04 | validation step 2000 | train loss: 1.5381, train acc: 0.4535 | valid loss: 1.5800, valid acc: 0.4473
# Epoch 05 | validation step 2400 | train loss: 1.5041, train acc: 0.4677 | valid loss: 1.5432, valid acc: 0.4579
# Epoch 06 | validation step 2800 | train loss: 1.4714, train acc: 0.4752 | valid loss: 1.5368, valid acc: 0.4567
# Epoch 07 | validation step 3200 | train loss: 1.4513, train acc: 0.4838 | valid loss: 1.5337, valid acc: 0.4618
# Epoch 08 | validation step 3600 | train loss: 1.4271, train acc: 0.4919 | valid loss: 1.5038, valid acc: 0.4701
# Epoch 09 | validation step 4000 | train loss: 1.3920, train acc: 0.5090 | valid loss: 1.4455, valid acc: 0.4902
# Epoch 10 | validation step 4400 | train loss: 1.3805, train acc: 0.5116 | valid loss: 1.4469, valid acc: 0.4936
# Epoch 11 | validation step 4800 | train loss: 1.3615, train acc: 0.5156 | valid loss: 1.4324, valid acc: 0.5006
# Epoch 12 | validation step 5200 | train loss: 1.3434, train acc: 0.5232 | valid loss: 1.4594, valid acc: 0.4827
# Epoch 13 | validation step 5600 | train loss: 1.3284, train acc: 0.5276 | valid loss: 1.4646, valid acc: 0.4818
# Epoch 14 | validation step 6000 | train loss: 1.3128, train acc: 0.5345 | valid loss: 1.4219, valid acc: 0.4998
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>█▆▄▃▂▂▂▂▂▁▁▂▂▂▂</td></tr><tr><td>grad_norms/layer_1</td><td>▇▆▂▁▁▂▁▂▃▂▄▆▆▇█</td></tr><tr><td>grad_norms/layer_2</td><td>▇█▅▅▅▄▄▃▃▂▂▂▁▁▁</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▃▄▅▅▆▆▆▇▇▇▇███</td></tr><tr><td>metrics/train_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▂▄▄▅▆▆▆▆▇██▇▇█</td></tr><tr><td>metrics/valid_loss</td><td>█▇▅▅▄▃▃▃▃▁▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>2.28787</td></tr><tr><td>grad_norms/layer_1</td><td>1.40639</td></tr><tr><td>grad_norms/layer_2</td><td>1.20992</td></tr><tr><td>metrics/test_accuracy</td><td>0.5101</td></tr><tr><td>metrics/train_accuracy</td><td>0.5345</td></tr><tr><td>metrics/train_loss</td><td>1.31283</td></tr><tr><td>metrics/valid_accuracy</td><td>0.4998</td></tr><tr><td>metrics/valid_loss</td><td>1.42186</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/8z0briyh' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/8z0briyh</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 4 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_200226-8z0briyh\logs</code>
# Launched CIFAR-10 sweep: snxiru39
# Launching CIFAR-10 sweep for activation=tanh, weights_init=xavier
# Create sweep with ID: c1wrvp10
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/c1wrvp10
# wandb: Agent Starting Run: e3j1v7dc with config:
# wandb: 	activation: tanh
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: xavier
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_200824-e3j1v7dc</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/e3j1v7dc' target="_blank">wise-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/c1wrvp10' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/c1wrvp10</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/c1wrvp10' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/c1wrvp10</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/e3j1v7dc' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/e3j1v7dc</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: xavier
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 1.8955, train acc: 0.3234 | valid loss: 1.7724, valid acc: 0.3694
# Epoch 01 | validation step 0800 | train loss: 1.7083, train acc: 0.3923 | valid loss: 1.7513, valid acc: 0.3705
# Epoch 02 | validation step 1200 | train loss: 1.6332, train acc: 0.4167 | valid loss: 1.6321, valid acc: 0.4161
# Epoch 03 | validation step 1600 | train loss: 1.5838, train acc: 0.4360 | valid loss: 1.5929, valid acc: 0.4329
# Epoch 04 | validation step 2000 | train loss: 1.5452, train acc: 0.4494 | valid loss: 1.5901, valid acc: 0.4276
# Epoch 05 | validation step 2400 | train loss: 1.5190, train acc: 0.4592 | valid loss: 1.5307, valid acc: 0.4610
# Epoch 06 | validation step 2800 | train loss: 1.4943, train acc: 0.4666 | valid loss: 1.5085, valid acc: 0.4595
# Epoch 07 | validation step 3200 | train loss: 1.4548, train acc: 0.4806 | valid loss: 1.5302, valid acc: 0.4573
# Epoch 08 | validation step 3600 | train loss: 1.4453, train acc: 0.4859 | valid loss: 1.5273, valid acc: 0.4614
# Epoch 09 | validation step 4000 | train loss: 1.4328, train acc: 0.4892 | valid loss: 1.4906, valid acc: 0.4724
# Epoch 10 | validation step 4400 | train loss: 1.4109, train acc: 0.4947 | valid loss: 1.4852, valid acc: 0.4696
# Epoch 11 | validation step 4800 | train loss: 1.3934, train acc: 0.5007 | valid loss: 1.4893, valid acc: 0.4668
# Epoch 12 | validation step 5200 | train loss: 1.3866, train acc: 0.5051 | valid loss: 1.5035, valid acc: 0.4665
# Epoch 13 | validation step 5600 | train loss: 1.3742, train acc: 0.5083 | valid loss: 1.4872, valid acc: 0.4722
# Epoch 14 | validation step 6000 | train loss: 1.3632, train acc: 0.5147 | valid loss: 1.5052, valid acc: 0.4665
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>█▅▃▂▂▁▂▁▂▂▂▃▄▄▄</td></tr><tr><td>grad_norms/layer_1</td><td>▃▃▃▃▂▃▃▁▃▄▄▅▆▇█</td></tr><tr><td>grad_norms/layer_2</td><td>▁▄▆▆▇██▅▆█▆▆▆▅▆</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▄▄▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>metrics/train_loss</td><td>█▆▅▄▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▁▄▅▅▇▇▇▇██████</td></tr><tr><td>metrics/valid_loss</td><td>█▇▅▄▄▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>2.25711</td></tr><tr><td>grad_norms/layer_1</td><td>1.39791</td></tr><tr><td>grad_norms/layer_2</td><td>1.07575</td></tr><tr><td>metrics/test_accuracy</td><td>0.4719</td></tr><tr><td>metrics/train_accuracy</td><td>0.51472</td></tr><tr><td>metrics/train_loss</td><td>1.36318</td></tr><tr><td>metrics/valid_accuracy</td><td>0.4665</td></tr><tr><td>metrics/valid_loss</td><td>1.50525</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wise-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/e3j1v7dc' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/e3j1v7dc</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 4 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_200824-e3j1v7dc\logs</code>
# Launched CIFAR-10 sweep: c1wrvp10
# Launching CIFAR-10 sweep for activation=sigmoid, weights_init=xavier
# Create sweep with ID: n64w6j1d
# Sweep URL: https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/n64w6j1d
# wandb: Agent Starting Run: 5653pr7i with config:
# wandb: 	activation: sigmoid
# wandb: 	batch_size: 100
# wandb: 	l2_coeff: 0.001
# wandb: 	learning_rate: 0.0005
# wandb: 	n_hidden_units: 256
# wandb: 	num_epochs: 15
# wandb: 	num_hidden_layers: 2
# wandb: 	optimizer: adam
# wandb: 	weights_init: xavier
# Ignoring project 'cifar10-ffnn' when running a sweep.
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>c:\Users\jakub\Skrivebord\Kandidatuddannelse\Semester 2\Deep learning\project\code\Deep-learning-\wandb\run-20251125_201143-5653pr7i</code>
# Syncing run <strong><a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5653pr7i' target="_blank">brisk-sweep-1</a></strong> to <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/n64w6j1d' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/n64w6j1d</a>
#  View project at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a>
#  View sweep at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/n64w6j1d' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/sweeps/n64w6j1d</a>
#  View run at <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5653pr7i' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5653pr7i</a>
# wandb: WARNING Config item 'activation' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'weights_init' was locked by 'sweep' (ignored update).
# wandb:	weights_init: xavier
# number of classes 10
# Epoch 00 | validation step 0400 | train loss: 2.0636, train acc: 0.2666 | valid loss: 1.9217, valid acc: 0.3182
# Epoch 01 | validation step 0800 | train loss: 1.8460, train acc: 0.3453 | valid loss: 1.8212, valid acc: 0.3588
# Epoch 02 | validation step 1200 | train loss: 1.7814, train acc: 0.3681 | valid loss: 1.7813, valid acc: 0.3704
# Epoch 03 | validation step 1600 | train loss: 1.7328, train acc: 0.3871 | valid loss: 1.7162, valid acc: 0.3944
# Epoch 04 | validation step 2000 | train loss: 1.7002, train acc: 0.3967 | valid loss: 1.7164, valid acc: 0.3858
# Epoch 05 | validation step 2400 | train loss: 1.6728, train acc: 0.4073 | valid loss: 1.6815, valid acc: 0.4005
# Epoch 06 | validation step 2800 | train loss: 1.6505, train acc: 0.4130 | valid loss: 1.6591, valid acc: 0.4146
# Epoch 07 | validation step 3200 | train loss: 1.6370, train acc: 0.4187 | valid loss: 1.7144, valid acc: 0.3784
# Epoch 08 | validation step 3600 | train loss: 1.6195, train acc: 0.4227 | valid loss: 1.6452, valid acc: 0.4108
# Epoch 09 | validation step 4000 | train loss: 1.5965, train acc: 0.4321 | valid loss: 1.6337, valid acc: 0.4149
# Epoch 10 | validation step 4400 | train loss: 1.5872, train acc: 0.4352 | valid loss: 1.6351, valid acc: 0.4141
# Epoch 11 | validation step 4800 | train loss: 1.5796, train acc: 0.4380 | valid loss: 1.6471, valid acc: 0.4146
# Epoch 12 | validation step 5200 | train loss: 1.5591, train acc: 0.4443 | valid loss: 1.5829, valid acc: 0.4421
# Epoch 13 | validation step 5600 | train loss: 1.5487, train acc: 0.4504 | valid loss: 1.5725, valid acc: 0.4435
# Epoch 14 | validation step 6000 | train loss: 1.5393, train acc: 0.4519 | valid loss: 1.6138, valid acc: 0.4305
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>global_step</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_0</td><td>▁▂▃▄▅▅▅▆▆▇▇▇▇██</td></tr><tr><td>grad_norms/layer_1</td><td>▁▁▂▂▃▄▄▅▅▅▆▇▇▇█</td></tr><tr><td>grad_norms/layer_2</td><td>▁▄▇▁▄▃▃█▆▁▆█▁▂▄</td></tr><tr><td>metrics/test_accuracy</td><td>▁</td></tr><tr><td>metrics/train_accuracy</td><td>▁▄▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>metrics/train_loss</td><td>█▅▄▄▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>metrics/valid_accuracy</td><td>▁▃▄▅▅▆▆▄▆▆▆▆██▇</td></tr><tr><td>metrics/valid_loss</td><td>█▆▅▄▄▃▃▄▂▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>14</td></tr><tr><td>global_step</td><td>6000</td></tr><tr><td>grad_norms/layer_0</td><td>0.9069</td></tr><tr><td>grad_norms/layer_1</td><td>0.41763</td></tr><tr><td>grad_norms/layer_2</td><td>0.85198</td></tr><tr><td>metrics/test_accuracy</td><td>0.44</td></tr><tr><td>metrics/train_accuracy</td><td>0.4519</td></tr><tr><td>metrics/train_loss</td><td>1.53927</td></tr><tr><td>metrics/valid_accuracy</td><td>0.4305</td></tr><tr><td>metrics/valid_loss</td><td>1.61378</td></tr><tr><td>+9</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">brisk-sweep-1</strong> at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5653pr7i' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn/runs/5653pr7i</a><br> View project at: <a href='https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn' target="_blank">https://wandb.ai/jakubbouzan-danmarks-tekniske-universitet-dtu/cifar10-ffnn</a><br>Synced 4 W&B file(s), 7 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251125_201143-5653pr7i\logs</code>
# Launched CIFAR-10 sweep: n64w6j1d

# %% [markdown]
# #### Summary CIFAR-10 comparing activation functions and initializations (local only)

# %%
# ==============================================================
# Summarise CIFAR-10 activation/initialisation performance (local only)
# ==============================================================
summaries = summarize_activation_init_performance(
    project="cifar10-ffnn",
    # entity="jakubbouzan",  # set if needed
    print_table=False,
)

if summaries:
    summary_table_df = build_activation_init_summary_dataframe(summaries)
    display(summary_table_df)

    import pandas as pd
    raw_df = pd.DataFrame(summaries)
    pivot_df = raw_df.pivot(
        index="activation",
        columns="weights_init",
        values="best_valid_acc_mean",
    )
    fig, ax = plt.subplots(figsize=(6, 4))
    pivot_df.plot(kind="bar", ax=ax)
    ax.set_ylabel("Mean Best Validation Accuracy")
    ax.set_xlabel("Activation")
    ax.set_title("CIFAR-10: Activation vs. Initialisation Performance")
    ax.set_ylim(0, 1)
    ax.legend(title="Initialisation")
    plt.tight_layout()
    plt.show()
else:
    print("No CIFAR-10 runs were found to summarise. Ensure sweeps finished and try again.")
# Out:
#   Activation Weights Init  Run Count  Best Validation Mean  \
# 0       relu           he          1                0.5006
# 1       tanh       xavier          1                0.4724
# 2    sigmoid       xavier          1                0.4435
#
#    Best Validation Max  Final Validation Mean  Final Validation Max  \
# 0               0.5006                 0.4998                0.4998
# 1               0.4724                 0.4665                0.4665
# 2               0.4435                 0.4305                0.4305
#
#    Final Training Mean  Final Training Max
# 0             0.534500            0.534500
# 1             0.514725            0.514725
# 2             0.451900            0.451900
